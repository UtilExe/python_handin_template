# %% [markdown]
# # Week 2 handin

# %% [markdown]
# ## 01 Assignment
# This is the hand-in for week2. Topics: Loops, Functions, Modules, argparse, Working with Files

# %% [markdown]
# ## 02 Status
# I have completed all the necessary tasks, besides from making the functions from Exercise 2 runable through Command-line. Need to investigate how to handle it with that file

# %% [markdown]
# ## Exercise 1
# 1. Create a python file with 3 functions:
#
#    A. def print_file_content(file) that can print content of a csv file to the console
#
#    B. def write_list_to_file(output_file, lst) that can take a list of tuple and write each element to a new line in file
#         a. rewrite the function so that it gets an arbitrary number of strings instead of a list
#
#    C. def read_csv(input_file) that take a csv file and read each row into a list
#
#
# 2. Add a functionality so that the file can be called from cli with 2 arguments
#        A. path to csv file
#        B. an argument --file file_name that if given will write the content to file_name or otherwise will print it to the console.
# 3. Add a --help cli argument to describe how the module is used

# %% [markdown]
# ## Exercise 2
# Create a module called utils.py with the following 5 functions:
#
# def get_file_names(folderpath,out=output.txt):
#     """ takes a path to a folder and writes all filenames in the folder to a specified output file"""
#
# def get_all_file_names(folderpath,out=output.txt):
#     """takes a path to a folder and write all filenames recursively (files of all sub folders to)"""
#
# def print_line_one(file_names):
#     """takes a list of filenames and print the first line of each"""
#
# def print_emails(file_names):
#     """takes a list of filenames and print each line that contains an email (just look for @)"""
#
# def write_headlines(md_files, out=output.txt):
#     """takes a list of md files and writes all headlines (lines starting with #) to a file"""
#
# Make sure your module can be called both from cli and imported to another module Create a new module that imports utils.py and test each function.

# %% [markdown]
# ## 03 Solution part 1

# %%
# Exercise 1.1 - Create a python file with 3 functions:

# %%
# Exercise 1.1.A - def print_file_content(file) that can print content of a csv file to the console

# %%
from modules import webget
import csv
def print_file_content(url):
    webget.download(url)

    with open('CAN.csv') as f:
        reader = csv.reader(f)
        header_row = next(reader)
        for row in reader:
            print('Row #' + str(reader.line_num) + ' ' + str(row))

url = 'http://climatedataapi.worldbank.org/climateweb/rest/v1/country/cru/tas/year/CAN.csv'
print_file_content(url)
# Out:
# Row #2 ['1901', '-7.67241907119751']
# Row #3 ['1902', '-7.862711429595947']
# Row #4 ['1903', '-7.910782814025879']
# Row #5 ['1904', '-8.155729293823242']
# Row #6 ['1905', '-7.547311305999756']
# Row #7 ['1906', '-7.684103488922119']
# Row #8 ['1907', '-8.413553237915039']
# Row #9 ['1908', '-7.790929317474365']
# Row #10 ['1909', '-8.23930549621582']
# Row #11 ['1910', '-7.774611473083496']
# Row #12 ['1911', '-8.114446640014648']
# Row #13 ['1912', '-7.885402679443359']
# Row #14 ['1913', '-7.987940311431885']
# Row #15 ['1914', '-7.965937614440918']
# Row #16 ['1915', '-7.144039154052734']
# Row #17 ['1916', '-8.132978439331055']
# Row #18 ['1917', '-8.499914169311523']
# Row #19 ['1918', '-8.204662322998047']
# Row #20 ['1919', '-8.035985946655273']
# Row #21 ['1920', '-7.830679893493652']
# Row #22 ['1921', '-7.685777187347412']
# Row #23 ['1922', '-8.334989547729492']
# Row #24 ['1923', '-8.022125244140625']
# Row #25 ['1924', '-7.574568271636963']
# ...

# %%
# Solution 2 (without using webget, for exercise 1.1A)
def print_file_content_2(path):
    with open(path) as f:
        reader = csv.reader(f)
        header_row = next(reader)
        for row in reader:
            print('Row #' + str(reader.line_num) + ' ' + str(row))
            
print_file_content_2('file_data/tracking.csv');
# Out:
# Row #2 ['64685a65-b5e9-4119-9deb-806db0d3e8e8', 'bymodel-3d-kobenhavn', '5617', '222']
# Row #3 ['67ea0857-bd24-4b3b-a18d-9052d52ff0da', 'grundkort', '3917', '87']
# Row #4 ['a8816a15-0609-4e3b-baca-897aedcbc9ac', 'trafiktal', '3684', '49']
# Row #5 ['314992c9-0b2d-4aa1-88d7-fdeb8664bfba', 'parkeringspladser', '2453', '22']
# Row #6 ['78d1107a-4f2f-4654-8a30-936c016c4a0d', 'parkomat-transaktioner', '1798', '30']
# Row #7 ['76ecf368-bf2d-46a2-bcf8-adaf37662528', 'befolkningen-efter-ar-bydel-alder-og-statsborgerskab', '1760', '38']
# Row #8 ['9fc2f1bb-acfa-4199-8084-5fabbc06f599', 'flaske-og-glascontainere', '1756', '36']
# Row #9 ['9070067f-ab57-41cd-913e-bc37bfaf9acd', 'befolkningen-efter-ar-bydel-alder-kon-og-civilstand', '1713', '32']
# Row #10 ['fdc1be48-5f61-4d62-924b-c896c0242205', 'hojdekurver', '1521', '44']
# Row #11 ['a5b929e5-c946-4ee0-974b-0097081f5a01', 'luftforurening', '1494', '19']
# Row #12 ['35e778ae-1849-43a0-bbbd-1966d04fe30e', 'trafikskilte', '1414', '19']
# ...

# %%
# Exercise 1.1.B - def write_list_to_file(output_file, lst) that can take a list of tuple and write each element 
# to a new line in file

# %%
def write_list_to_file(output_file, tupleL):
    with open(output_file, 'w') as file_object:
        for numb in tupleL:
            # "write() argument must be str, not int".. manually converting to str, in case it's numbers
            file_object.write(str(numb) + '\n')


tupleList = ('hello', 'there', 'okay', 1, 6, 7, 9, 11, "hello@hotmail.com")

write_list_to_file('file_data/datamsg.txt', tupleList)

# %%
# Exercise 1.1.B.a - rewrite the function so that it gets an arbitrary number of strings instead of a list
def write_list_to_file_arbitrary(output_file, *numbers):
    with open(output_file, 'w') as file_object:
        for numb in numbers:
            # "write() argument must be str, not int"next manually converting to str.
            file_object.write(str(numb) + '\n')

write_list_to_file_arbitrary('file_data/datamsg2.txt', 'hi', 'im', 'data', 1, 6, 7, 9, 11, "new", "test@gmail.com")

# %%
# Exercise 1.1.C - def read_csv(input_file) that take a csv file and read each row into a list

# %%
def read_csv(input_file):
    with open(input_file) as f:
        rowList = []
        reader = csv.reader(f)
        # why it skips first row: https://www.kite.com/python/answers/how-to-skip-the-first-line-of-a-csv-file-in-python
        header_row = next(reader)

        for row in reader:
            # add to the new list
            rowList.append(row)
    # contains one combined list.
    for items in rowList:
        print(items)
 #   print(rowList)

read_csv('file_data/data.csv');
# Out:
# ['and', 'this', 'is', 'the', 'second', 'line']
# ['but', 'this', 'is', 'the', 'third', 'line']
# ['continues', 'to', 'print']

# %% [markdown]
# ## 04 Solution part 2

# %%
# Create a module called utils.py with the following 5 functions:
# Util functions: python_handin_template/modules/utils2.py
from modules import utils2
print("Exercise 2")
print("Get file names (writing to file output.txt)")
utils2.get_file_names('./')
print("Get all file names (writing to file output2.txt")
utils2.get_all_file_names('./')
print("Print first line of file:")
utils2.print_line_one('file_data/datamsg2.txt', 'file_data/datamsg.txt')
print("Print all rows containing email (@ validation):")
utils2.print_emails('file_data/datamsg2.txt', 'file_data/datamsg.txt')
print("Write all rows containing headline of MD files (# validation), to file")
utils2.write_headlines('README.md', 'file_data/README.md')
# Out:
# Exercise 2
# Get file names (writing to file output.txt)
# Get all file names (writing to file output2.txt
# Print first line of file:
# File: file_data/datamsg2.txt: hi
# File: file_data/datamsg.txt: hello
# Print all rows containing email (@ validation):
# File: file_data/datamsg2.txt: test@gmail.com
# File: file_data/datamsg.txt: hello@hotmail.com
# Write all rows containing headline of MD files (# validation), to file
